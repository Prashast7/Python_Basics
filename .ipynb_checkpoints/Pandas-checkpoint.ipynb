# %%
import pandas as pd

# %%
orders_df = pd.read_csv('orders.txt')

# %%
orders_df.head()
# Out:
#          order_id  order_date     customer_name           city  \
# 0  CA-2018-100006  2018-09-07       Dennis Kane  New York City
# 1  CA-2018-100090  2018-07-08        Ed Braxton  San Francisco
# 2  CA-2018-100293  2018-03-14  Neil Französisch   Jacksonville
# 3  CA-2018-100328  2018-01-28   Jasper Cacioppo  New York City
# 4  CA-2018-100363  2018-04-08       Jim Mitchum       Glendale
#
#           category       product_id    sales    profit
# 0       Technology  TEC-PH-10002075  377.970  109.6113
# 1        Furniture  FUR-TA-10003715  502.488  -87.9354
# 2  Office Supplies  OFF-PA-10000176   91.056   31.8696
# 3  Office Supplies  OFF-BI-10000343    3.928    1.3257
# 4  Office Supplies  OFF-FA-10000611    2.368    0.8288

# %%
orders_df.iloc[0:3,0:7]
# Out:
#          order_id  order_date     customer_name           city  \
# 0  CA-2018-100006  2018-09-07       Dennis Kane  New York City
# 1  CA-2018-100090  2018-07-08        Ed Braxton  San Francisco
# 2  CA-2018-100293  2018-03-14  Neil Französisch   Jacksonville
#
#           category       product_id    sales
# 0       Technology  TEC-PH-10002075  377.970
# 1        Furniture  FUR-TA-10003715  502.488
# 2  Office Supplies  OFF-PA-10000176   91.056

# %%
orders_df.loc[1:5,['city','category']]
# Out:
#             city         category
# 1  San Francisco        Furniture
# 2   Jacksonville  Office Supplies
# 3  New York City  Office Supplies
# 4       Glendale  Office Supplies
# 5  New York City  Office Supplies

# %%
orders_df['category'].unique()
# Out:
# array(['Technology', 'Furniture', 'Office Supplies'], dtype=object)

# %%
orders_df[['category','city']].value_counts()
orders_df.iloc[::100]
# Out:
# category         city
# Office Supplies  New York City    257
#                  Los Angeles      210
# Furniture        New York City    157
# Office Supplies  Philadelphia     152
#                  San Francisco    149
#                                  ...
# Furniture        Boise              1
#                  Bossier City       1
# Technology       Thousand Oaks      1
#                  Toledo             1
#                  Spokane            1
# Name: count, Length: 987, dtype: int64

# %%
index =  [i for i in range(len(orders_df)) if i % 100 == 0]
idf = orders_df.iloc[index]
idf.head()
# Out:
#            order_id  order_date      customer_name           city  \
# 0    CA-2018-100006  2018-09-07        Dennis Kane  New York City
# 100  CA-2018-107573  2018-12-12       Philip Brown          Miami
# 200  CA-2018-115791  2018-01-16  Delfina Latchford   Philadelphia
# 300  CA-2018-124723  2018-08-05      Gary Zandusky     Texas City
# 400  CA-2018-132500  2018-09-08      Gary Zandusky  San Francisco
#
#             category       product_id    sales    profit
# 0         Technology  TEC-PH-10002075  377.970  109.6113
# 100  Office Supplies  OFF-EN-10001099   23.472    7.6284
# 200        Furniture  FUR-FU-10001095  127.104   28.5984
# 300        Furniture  FUR-TA-10001307  489.230   41.9340
# 400       Technology  TEC-AC-10001383   49.980    8.4966

# %%
dx = orders_df[
(orders_df['category']== 'furniture')
& (orders_df['sales'] >= 1000) 
& (orders_df['sales'] <= 1200)
]
dx.head()
# Out:
#            order_id  order_date      customer_name            city   category  \
# 40   CA-2018-103100  2018-12-20      Adrian Barton    Indianapolis  furniture
# 53   CA-2018-103660  2018-08-25       Mitch Webber         Seattle  furniture
# 86   CA-2018-106376  2018-12-05      Brendan Sweed         Gilbert  furniture
# 155  CA-2018-111871  2018-03-18      Eileen Kiefer   San Francisco  furniture
# 322  CA-2018-126361  2018-08-04  Valerie Dominguez  Pleasant Grove  furniture
#
#           product_id     sales    profit
# 40   OFF-BI-10004600  1103.970  496.7865
# 53   TEC-PH-10000895  1007.944   75.5958
# 86   OFF-AR-10002671  1113.024  111.3024
# 155  FUR-BO-10004218  1198.330   70.4900
# 322  OFF-AP-10003590  1089.750  305.1300

# %%
dy = orders_df[
(orders_df['profit'] < 0)
&(orders_df['city'].isin(['Los Angeles','Seattle']))
]
dy.head()
# Out:
#            order_id  order_date      customer_name         city   category  \
# 27   CA-2018-101931  2018-10-28       Todd Sumrall  Los Angeles  furniture
# 87   CA-2018-106439  2018-10-31       Greg Guthrie  Los Angeles  furniture
# 315  CA-2018-125829  2018-11-04      William Brown  Los Angeles  furniture
# 763  CA-2018-166471  2018-08-09  Matthew Grinstein      Seattle  furniture
# 832  CA-2019-102316  2019-03-01      Dave Hallsten  Los Angeles  furniture
#
#           product_id    sales   profit
# 27   FUR-BO-10001337  616.998 -36.2940
# 87   FUR-CH-10003833  146.352  -9.1470
# 315  FUR-TA-10002041  573.728 -64.5444
# 763  TEC-PH-10000038  219.168 -43.8336
# 832  FUR-CH-10003396  184.752 -20.7846

# %%
office_supplies_df = orders_df[orders_df['category'] == 'Office Supplies']

# Get the unique list of cities
unique_cities = office_supplies_df['city'].unique()

# Display the unique list of cities
print(unique_cities)
# Out:
# []

# %%
orders_df = pd.read_csv('orders.txt')
ny_df = orders_df[orders_df['city']=='New York City']
nc_df = ny_df['category'].value_counts()
print(nc_df)
orders_df.head()
# Out:
# category
# Office Supplies    257
# Furniture          157
# Technology          36
# Name: count, dtype: int64
#          order_id  order_date     customer_name           city  \
# 0  CA-2018-100006  2018-09-07       Dennis Kane  New York City
# 1  CA-2018-100090  2018-07-08        Ed Braxton  San Francisco
# 2  CA-2018-100293  2018-03-14  Neil Französisch   Jacksonville
# 3  CA-2018-100328  2018-01-28   Jasper Cacioppo  New York City
# 4  CA-2018-100363  2018-04-08       Jim Mitchum       Glendale
#
#           category       product_id    sales    profit
# 0       Technology  TEC-PH-10002075  377.970  109.6113
# 1        Furniture  FUR-TA-10003715  502.488  -87.9354
# 2  Office Supplies  OFF-PA-10000176   91.056   31.8696
# 3  Office Supplies  OFF-BI-10000343    3.928    1.3257
# 4  Office Supplies  OFF-FA-10000611    2.368    0.8288
